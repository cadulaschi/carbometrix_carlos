# %% [markdown]
# ## Data analysis if the biggest automotive companies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('CSV_files/Automotive_CDP.csv')
total_companies = data.shape[0]

# %%
data.head()
# Out:
#    Unnamed: 0                                              Title  \
# 0           0       General Motors Company - Climate Change 2018
# 1           1  Mitsubishi Motors Corporation - Climate Change...
# 2           2  Fiat Chrysler Automobiles NV - Climate Change ...
# 3           3                       BMW AG - Climate Change 2020
# 4           4     Toyota Motor Corporation - Climate Change 2020
#
#        Start Date                 End Date Currency   Reporting_boundary  \
# 0  janvier 1 2017  d\xc3\xa9cembre 31 2017      USD  Operational control
# 1    April 1 2019            March 31 2020      JPY    Financial control
# 2  January 1 2018         December 31 2018      EUR  Operational control
# 3  January 1 2019         December 31 2019      EUR  Operational control
# 4  January 1 2019         December 31 2019      JPY    Financial control
#
#      Scope 1 Scope 2 (location based) Scope 2 (market based)  \
# 0  1848804.0                  4572734                4302887
# ...

# %%
emissions = data.transpose().iloc[6:]
emissions = emissions.replace('<Not Applicable>', np.nan)
name_emissions = list(emissions.index)

# %%
i = 0
mean_emissions = np.zeros(len(emissions))
for s in np.array(emissions, dtype=float):
    s = s[np.logical_not(np.isnan(s))] #do not count companies with nan 
    mean_emissions[i] = np.mean(s)        
    i += 1

# %%
y_pos = np.arange(len(name_emissions))

fig, ax = plt.subplots(figsize=(20,12))

ax.barh(y_pos, mean_emissions)
ax.set_yticks(y_pos)
ax.set_yticklabels(name_emissions)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('CO2eq')
ax.set_title('Mean of Emissions (all scopes, absolute value)')

plt.show()

# %% [markdown]
# ## 1st analysis
#
#
# Pour le secteur automobile en général et pour chaque entreprise, la part de chaque scope sur l'empreinte carbone totale de l'entreprise (en % des émissions totales). Une sortie graphique pourrait permettre d'illustrer les valeurs numériques.

# %%
name = emissions.transpose().columns.values
name = name.tolist()

# %%
emissions_test = emissions.replace(np.nan, 0)
emissions_test = np.array(emissions_test, dtype=float)

# %%
sum_emissions = emissions_test.sum(axis=0)
#replace zero by inf to avoid divide by zero
sum_emissions = np.where(sum_emissions == 0, np.inf, sum_emissions)

# %%
#change to percentage all companies
percentage_emission = 100 * emissions_test.T / sum_emissions[:,None]
#percentage mean
percentage_mean = 100 * mean_emissions / mean_emissions.sum(axis=0)

# %%
df = pd.DataFrame(data=percentage_emission, columns=name)

# %%
df = df.transpose()
df["Mean"] = percentage_mean

# %%
df
# Out:
#                                                             0          1  \
# Scope 1                                              0.634076   0.320794
# Scope 2 (location based)                             1.568291   1.063026
# Scope 2 (market based)                               1.475742   1.146869
# Purchased goods and services                        15.836122  17.416643
# Capital goods                                        1.576382   0.877598
# Fuel-and-energy-related activities (not include...   0.121602   0.135659
# Upstream transportation and distribution             1.038863   3.228599
# Waste generated in operations                        0.022674   0.057773
# Business travel                                      0.017195   0.011505
# Employee commuting                                   0.046300   0.038986
# Upstream leased assets                               0.003456   0.000000
# Downstream transportation and distribution           0.551891   0.000000
# ...

# %%
data['Title'].shape
# Out:
# (62,)

# %%
df.insert(0, 'Title', data['Title'])

# %%
#scope 1
title = data.iloc[1]
scope1 = np.array(data.iloc[6], dtype=float)
total_companies
# Out:
# 62

# %%
#nb of nan aswer
nb_nan_answer = scope1[np.isnan(scope1)].shape[0]
#who did not answere
company_nan_answer = np.argwhere(np.isnan(scope1))

# %%
scope1_sorted = scope1[scope1.argsort()]
scope1_sorted = scope1_sorted[:-nb_nan_answer]

# %%
total_scope1 = scope1_sorted.sum()
total_scope1
# Out:
# 54332303.53

# %%
df = df.replace(['None','<Not Applicable>'], np.nan)  # equivalent to "no answer"
df = df.apply(pd.to_numeric, errors='ignore') # convert type to numeric (float64) if only numeric values in col

# convert date from string to datetime64[ns]
df['Start Date'] = df['Start Date'].apply(lambda x: x.replace('\\xc3\\xa9','é'))
df['End Date'] = df['End Date'].apply(lambda x: x.replace('\\xc3\\xa9','é'))
df['Start Date'] = df['Start Date'].apply(lambda x: dateparser.parse(x))
df['End Date'] = df['End Date
import dateparser

# %%
# split 'Title' col into Company & Report year
df[['Company','Report year']] = df['Title'].str.split('-', n=1, expand=True)
# convert date from string to datetime64[ns]
df['Start Date'] = df['Start Date'].apply(lambda x: x.replace('\\xc3\\xa9','é'))
df['End Date'] = df['End Date'].apply(lambda x: x.replace('\\xc3\\xa9','é'))
df['Start Date'] = df['Start Date'].apply(lambda x: dateparser.parse(x))
df['End Date'] = df['End Date'].apply(lambda x: dateparser.parse(x))

# %%
# split 'Title' col into Company & Report year
df[['Company','Report year']] = df['Title'].str.split('-', n=1, expand=True)
# convert date from string to datetime64[ns]
df['Start Date'] = df['Start Date'].apply(lambda x: x.replace('\\xc3\\xa9','é'))
df['End Date'] = df['End Date'].apply(lambda x: x.replace('\\xc3\\xa9','é'))
df['Start Date'] = df['Start Date'].apply(lambda x: dateparser.parse(x))
df['End Date'] = df['End Date'].apply(lambda x: dateparser.parse(x))
